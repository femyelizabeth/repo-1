# %% [markdown]
# <a href="https://colab.research.google.com/github/femyelizabeth/repo-1/blob/main/Data%20science/iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/Iris.csv')

# %%
df.shape
# Out:
# (150, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
sns.set(style="whitegrid")

# %%
sns.histplot(df['SepalLengthCm'],bins=20,kde=True)
plt.title('Histogram of sepal length')
plt.xlabel('Sepal Length')
plt.ylabel('Frequency')
plt.show()

# %%
sns.boxplot(x='Species',y='SepalLengthCm',data=df)
plt.title('Box-plot of Sepal_length by species')
plt.show()

# %%
sns.kdeplot(df['SepalLengthCm'])
plt.title('Distribution of Sepal Length')
plt.show()

# %%
sns.scatterplot(x='SepalLengthCm',y='SepalWidthCm',hue='Species',data=df)
plt.title("Scatterplot of Sepal Length vs Sepal Width")
plt.show()

# %%
sns.scatterplot(x='PetalLengthCm',y='PetalWidthCm',hue='Species',data=df)
plt.title('Scatterplot of Petal Length vs Petal Width')
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm', size='PetalLengthCm', hue='Species', data=df, sizes=(30, 200), palette='viridis', alpha=0.7)
plt.title('Bubble Chart of Sepal Length vs Sepal Width with Petal Length as Bubble Size')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Sepal Width (cm)')
plt.show()

# %%
sns.set(style="whitegrid")

# Scatterplot Matrix (Pairplot)
sns.pairplot(df, hue='Species', markers=["o", "s", "D"], palette='viridis')
plt.suptitle('Scatterplot Matrix of Iris Dataset', y=1.02)
plt.show()

# %%
sns.scatterplot(x='SepalLengthCm',y='SepalWidthCm',size='PetalLengthCm',hue='Species',data=df)
plt.title('Bubble chart of sepal length vs sepal width')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.kdeplot(df['SepalLengthCm'], fill=True, color='skyblue')
plt.title('Density Chart of Sepal Length')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Density')
plt.show()

# %%
import matplotlib.pyplot as plt
from pandas.plotting import parallel_coordinates

plt.figure(figsize=(12, 8))
parallel_coordinates(df, 'Species', colormap='viridis')
plt.title('Parallel Coordinates Chart of Iris Dataset')
plt.show()

# %%
plt.figure(figsize=(10, 6))

# Plot the mean line
sns.lineplot(x='Species', y='SepalLengthCm', data=df, estimator='mean', color='blue', label='Mean')

# Plot the deviation area using a shaded region
sns.lineplot(x='Species', y='SepalLengthCm', data=df, estimator='std', color='orange', label='Deviation', ci='sd')

plt.title('Deviation Chart of Sepal Length by Species')
plt.xlabel('Species')
plt.ylabel('Sepal Length (cm)')
plt.legend()
plt.show()
# Out:
# <ipython-input-27-9b6b2b82543c>:7: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.lineplot(x='Species', y='SepalLengthCm', data=df, estimator='std', color='orange', label='Deviation', ci='sd')

# %%
sns.lineplot(x='Species',y='SepalLengthCm',data=df)
plt.title('Deviation chart of sepal length by species')
plt.xlabel('Species')
plt.ylabel('Sepal Length')
plt.xtricks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-35f8584c73a5> in <cell line: 5>()
#       3 plt.xlabel('Species')
#       4 plt.ylabel('Sepal Length')
# ----> 5 plt.xtricks(rotation=45)
#       6 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xtricks'

# %%
sns.lineplot(x='Species',y='PetalWidthCm',data=df)
plt.title('Deviation chart of petal width by species')
plt.xlabel('Species')
plt.ylabel('Petal Width')
sns.xtricks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-39-2d05268a1a7c> in <cell line: 5>()
#       3 plt.xlabel('Species')
#       4 plt.ylabel('Petal Width')
# ----> 5 sns.xtricks(rotation=45)
#       6 plt.show()
#
# AttributeError: module 'seaborn' has no attribute 'xtricks'

# %%
from pandas.plotting import parallel_coordinates


parallel_coordinates(df,'Species',colormap='viridis')
plt.title('Parallel Coordinates of Iris Dataset')

plt.show()

# %%
from pandas.plotting import andrews_curves
andrews_curves(df,'Species')
plt.title('Andrews Curves of iris Dataset')
plt.show()

# %%
print("First five rows")
print(df.head())
print("*********")
print("columns",df.columns)
print("*********")
print("shape:",df.shape)
print("*********")
print("Size:",df.size)
print("*********")
print("no of samples available for each type")
print(df['Species'].value_counts())
print("*********")
print(df.describe())
# Out:
# First five rows
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# *********
# columns Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')
# *********
# shape: (150, 6)
# *********
# Size: 900
# *********
# no of samples available for each type
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64
# *********
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# ...

# %%
import math
import operator

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
def euclideanDistance(data_1, data_2, data_len):
    dist = 0
    for i in range(data_len):
        dist = dist + np.square(data_1[i] - data_2[i])
    return np.sqrt(dist)

# %%
def knn(trainingSet, testInstance, k):

    distances = {}
    sort = {}

    length = testInstance.shape[1]

    for x in range(len(trainingSet)):

        dist = euclideanDistance(testInstance, trainingSet.iloc[x], length)

        distances[x] = dist[0]

    sorted_d = sorted(distances.items(), key=operator.itemgetter(1))


    neighbors = []


    for x in range(k):
        neighbors.append(sorted_d[x][0])
    counts = {"Iris-setosa":0,"Iris-versicolor":0,"Iris-virginica":0}


    for x in range(len(neighbors)):
        response = trainingSet.iloc[neighbors[x]][-1]

        if response in counts:
            counts[response] += 1
        else:
            counts[response] = 1

    print(counts)
    sortedVotes = sorted(counts.items(), key=operator.itemgetter(1), reverse=True)
    print(sortedVotes)
    return(sortedVotes[0][0], neighbors)

# %%
testSet = [[1.4, 3.6, 3.4, 1.2]]
test = pd.DataFrame(testSet)
result,neigh = knn(df, test, 4)#here we gave k=4
print("And the flower is:",result)
print("the neighbors are:",neigh)
# Out:
# {'Iris-setosa': 4, 'Iris-versicolor': 0, 'Iris-virginica': 0}
# [('Iris-setosa', 4), ('Iris-versicolor', 0), ('Iris-virginica', 0)]
# And the flower is: Iris-setosa
# the neighbors are: [1, 0, 2, 3]

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
x=df.iloc[:,:4] #all parameters
y=df["Species"] #class labels

# %%
neigh=KNeighborsClassifier(n_neighbors=4)
neigh.fit(df.iloc[:,:4],df["Species"])
# Out:
# KNeighborsClassifier(n_neighbors=4)

# %%
testSet = [[1.4, 3.6, 3.4, 1.2]]
test = pd.DataFrame(testSet)
print(test)
print("predicted:",neigh.predict(test))
print("neighbors",neigh.kneighbors(test))
# Out:
#      0    1    2    3
# 0  1.4  3.6  3.4  1.2
# predicted: ['Iris-setosa']
# neighbors (array([[1.5       , 1.56843871, 1.95448203, 2.81780056]]), array([[1, 0, 2, 3]]))
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
